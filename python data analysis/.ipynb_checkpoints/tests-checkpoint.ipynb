# %%
import pandas

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '_ENtro_to_arabesk.csv',
#  '_ENtro_to_neo_mellow.csv',
#  'aapl.csv',
#  'Beaty.csv',
#  'City_Beats.csv',
#  'tests.ipynb']

# %%
df1=pandas.read_csv("_ENtro_to_arabesk.csv")
df1
# Out:
#                                  Name                          Artist  \
# 0                          Kararsızım                      Ebru Yaşar
# 1                        Git Hadi Git                       Ismail YK
# 2                               Vebal                          Alişan
# 3                            Ölüm Var               Mahsun Kirmizigül
# 4                               Bozuk                           Dogus
# 5                          Sen Miydin                    Adnan Senses
# 6                           Etek Sarı                          Ceylan
# 7                  Bir Kalp Bos Kaldi                      Ümit Besen
# 8                        Aşksız Prens                    Rober Hatemo
# 9                                Iona                          Bergen
# 10                       Kadir Gecesi                Fatih Kisaparmak
# 11                         Gözbebeğim                            Baha
# ...

# %%
df1.set_index("Artist
              ")
# Out:
#   File "<ipython-input-16-8514f450cd22>", line 1
#     df1.set_index("Artist
#                          ^
# SyntaxError: EOL while scanning string literal

# %%
print("hello")
# Out:
# hello

# %%
df2=pandas.read_csv("City_Beats.csv")

# %%
print(df2)
# Out:
#                      Name             Artist                       Album  \
# 0               Panoramic             Lusine            The Waiting Room
# 1                   Lucky             Lusine            The Waiting Room
# 2            On Telegraph             Lusine            The Waiting Room
# 3             Toothwheels                Múm                  Smilewound
# 4  Be Good To Them Always          The Books  Lost and Safe (Remastered)
# 5                You Wish  Nightmares on Wax      In A Space Outta Sound
# 6     Riders On the Storm          Yonderboi        Shallow and Profound
# 7         Time to Pretend               MGMT        Oracular Spectacular
# 8                  Baffle             Lusine          A Certain Distance
# 9     Heavyweight Freight        Jon Kennedy         Useless Wooden Toys
#
#    Track Number
# 0             1
# 1             3
# 2             4
# 3             1
# 4             2
# 5             6
# 6            12
# 7             1
# ...

# %%
df2.set_index("Artist")
# Out:
#                                      Name                       Album  \
# Artist
# Lusine                          Panoramic            The Waiting Room
# Lusine                              Lucky            The Waiting Room
# Lusine                       On Telegraph            The Waiting Room
# Múm                           Toothwheels                  Smilewound
# The Books          Be Good To Them Always  Lost and Safe (Remastered)
# Nightmares on Wax                You Wish      In A Space Outta Sound
# Yonderboi             Riders On the Storm        Shallow and Profound
# MGMT                      Time to Pretend        Oracular Spectacular
# Lusine                             Baffle          A Certain Distance
# Jon Kennedy           Heavyweight Freight         Useless Wooden Toys
#
#                    Track Number
# Artist
# Lusine                        1
# Lusine                        3
# Lusine                        4
# Múm                           1
# ...

# %%
print("hey")
# Out:
# hey

# %%
print(df1.mean)
# Out:
# <bound method DataFrame.mean of                                  Name                          Artist  \
# 0                          Kararsızım                      Ebru Yaşar
# 1                        Git Hadi Git                       Ismail YK
# 2                               Vebal                          Alişan
# 3                            Ölüm Var               Mahsun Kirmizigül
# 4                               Bozuk                           Dogus
# 5                          Sen Miydin                    Adnan Senses
# 6                           Etek Sarı                          Ceylan
# 7                  Bir Kalp Bos Kaldi                      Ümit Besen
# 8                        Aşksız Prens                    Rober Hatemo
# 9                                Iona                          Bergen
# 10                       Kadir Gecesi                Fatih Kisaparmak
# 11                         Gözbebeğim                            Baha
# ...

# %%
print(df2.artist.mean)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-5e5788f207d9> in <module>()
# ----> 1 print(df2.artist.mean)
#
# /Users/DM-Alt/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'artist'

# %%
print(df2.mean)
# Out:
# <bound method DataFrame.mean of                      Name             Artist                       Album  \
# 0               Panoramic             Lusine            The Waiting Room
# 1                   Lucky             Lusine            The Waiting Room
# 2            On Telegraph             Lusine            The Waiting Room
# 3             Toothwheels                Múm                  Smilewound
# 4  Be Good To Them Always          The Books  Lost and Safe (Remastered)
# 5                You Wish  Nightmares on Wax      In A Space Outta Sound
# 6     Riders On the Storm          Yonderboi        Shallow and Profound
# 7         Time to Pretend               MGMT        Oracular Spectacular
# 8                  Baffle             Lusine          A Certain Distance
# 9     Heavyweight Freight        Jon Kennedy         Useless Wooden Toys
#
#    Track Number
# 0             1
# 1             3
# 2             4
# 3             1
# 4             2
# 5             6
# ...

# %%
print(df1+df2)
# Out:
#                                   Name                         Artist  \
# 0                  KararsızımPanoramic               Ebru YaşarLusine
# 1                    Git Hadi GitLucky                Ismail YKLusine
# 2                    VebalOn Telegraph                   AlişanLusine
# 3                  Ölüm VarToothwheels           Mahsun KirmizigülMúm
# 4          BozukBe Good To Them Always                 DogusThe Books
# 5                   Sen MiydinYou Wish  Adnan SensesNightmares on Wax
# 6         Etek SarıRiders On the Storm                CeylanYonderboi
# 7    Bir Kalp Bos KaldiTime to Pretend                 Ümit BesenMGMT
# 8                   Aşksız PrensBaffle             Rober HatemoLusine
# 9              IonaHeavyweight Freight              BergenJon Kennedy
# 10                                 NaN                            NaN
# 11                                 NaN                            NaN
# ...

# %%
df6=read_csv("supermarkets.csv")

# %%
print(df6)
# Out:
#    ID          Address            City             State Country  \
# 0   1     3666 21st St   San Francisco          CA 94114     USA
# 1   2   735 Dolores St   San Francisco          CA 94119     USA
# 2   3      332 Hill St   San Francisco  California 94114     USA
# 3   4     3995 23rd St   San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St   San Francisco        California     USA
# 5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#            Name  Employees
# 0       Madeira          8
# 1   Bready Shop         15
# 2   Super River         25
# 3    Ben's Shop         10
# 4       Sanchez         12
# 5    Richvalley         20

# %%
df7=pandas.read_json("supermarkets.json")
print(df7)
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7.pandas.set_Index("City")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-a2699e11c9d9> in <module>()
# ----> 1 df7.pandas.set_Index("City")
#
# /Users/DM-Alt/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pandas'

# %%
df8=pandas.read_json('http://pythonhow.com/supermarkets.json')

# %%
print(df8)
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df8.set_index("Address")
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df8.set_index?

# %%
df7.local[]
# Out:
#   File "<ipython-input-68-75e441cb8e2b>", line 1
#     df7.local[]
#               ^
# SyntaxError: invalid syntax

# %%
df7.loc["735 Dolores St":"332 Hill St","Country":"ID"]
# Out:
# Empty DataFrame
# Columns: [Country, Employees, ID]
# Index: []

# %%
df7.loc["735 Dolores St":"332 Hill St","Country":"ID"]
# Out:
# Empty DataFrame
# Columns: [Country, Employees, ID]
# Index: []

# %%
df7.set_index("Address")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/DM-Alt/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Address'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df7=pandas.read_json("supermarkets.json")

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7=df7.set_Index("City")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-ebfb8e86c401> in <module>()
# ----> 1 df7=df7.set_Index("City")
#
# /Users/DM-Alt/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'set_Index'

# %%
df7.set_index("City")
# Out:
#               Country  Employees  ID         Name             State
# City
# San Francisco     USA          8   1      Madeira          CA 94114
# San Francisco     USA         15   2  Bready Shop          CA 94119
# San Francisco     USA         25   3  Super River  California 94114
# San Francisco     USA         10   4   Ben's Shop          CA 94114
# San Francisco     USA         12   5      Sanchez        California
# San Francisco     USA         20   6   Richvalley          CA 94114

# %%
df7.loc["332 Hill St","Country":"Name"]
# Out:
# Country              USA
# Employees             25
# ID                     3
# Name         Super River
# Name: 332 Hill St, dtype: object

# %%
list(df7.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df7
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df7.iloc[1:3,1:3]
# Out:
#                Country  Employees
# Address
# 735 Dolores St     USA         15
# 332 Hill St        USA         25

# %%
df7.iloc[1:4,1:4]
# Out:
#                Country  Employees  ID
# Address
# 735 Dolores St     USA         15   2
# 332 Hill St        USA         25   3
# 3995 23rd St       USA         10   4

# %%
df7
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df7.iloc[1:5,1:5]
# Out:
#                 Country  Employees  ID         Name
# Address
# 735 Dolores St      USA         15   2  Bready Shop
# 332 Hill St         USA         25   3  Super River
# 3995 23rd St        USA         10   4   Ben's Shop
# 1056 Sanchez St     USA         12   5      Sanchez

# %%
df7.ix[3,"Name"]
# Out:
# "Ben's Shop"

# %%
df7.ix[3:6,"Name"]
# Out:
# Address
# 3995 23rd St       Ben's Shop
# 1056 Sanchez St       Sanchez
# 551 Alvarado St    Richvalley
# Name: Name, dtype: object

# %%
df7.drop(" 3995 23rd St",0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-f9054cabd6e5> in <module>()
# ----> 1 df7.drop(" 3995 23rd St",0)
#
# /Users/DM-Alt/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# /Users/DM-Alt/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# -> 3262                                  labels[mask])
#    3263             indexer = indexer[~mask]
# ...

# %%
df7=df7.set_index("Address")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/DM-Alt/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Address'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e51f5dd68a05> in <module>()
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
df1=pandas.read_csv("_ENtro_to_arabesk.csv")

# %% [markdown]
# df1

# %%
df1=pandas.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c6f9ac5eb66d> in <module>()
# ----> 1 df1=pandas.read_csv()
#
# TypeError: parser_f() missing 1 required positional argument: 'filepath_or_buffer'

# %%
import pandas

# %%
df1=pandas.read_csv("_ENtro_to_arabesk.csv")

# %%
df1
# Out:
#                                  Name                          Artist  \
# 0                          Kararsızım                      Ebru Yaşar
# 1                        Git Hadi Git                       Ismail YK
# 2                               Vebal                          Alişan
# 3                            Ölüm Var               Mahsun Kirmizigül
# 4                               Bozuk                           Dogus
# 5                          Sen Miydin                    Adnan Senses
# 6                           Etek Sarı                          Ceylan
# 7                  Bir Kalp Bos Kaldi                      Ümit Besen
# 8                        Aşksız Prens                    Rober Hatemo
# 9                                Iona                          Bergen
# 10                       Kadir Gecesi                Fatih Kisaparmak
# 11                         Gözbebeğim                            Baha
# ...
